# %%
import matplotlib.pyplot as plt
import numpy as np

speedup = [1, 3.64, 3.29, 8.11, 15.61]
sentiment = [82.23, 81.09, 79.42, 79.29, 79.05]
degradation = [(x-sentiment[0])/sentiment[0] for x in sentiment]
names = ['XLMR', 'XLRM-quant', 'MiniLM-L12', 'MiniLM-L12-quant', 'MiniLM-L6-quant']

# %%
order = np.argsort(sentiment)
speedup_ord = [speedup[i] for i in order]
deg_ord = [degradation[i] for i in order]
name_ord = [names[i] for i in order]

plt.figure(figsize=(10,10))
plt.plot(speedup_ord, deg_ord, 'o')
plt.xlabel('speedup')
plt.ylabel('degradation')
plt.grid()

for s, d, n in zip(speedup_ord, deg_ord, name_ord):
    plt.annotate(n, # this is the text
                     (s,d), # these are the coordinates to position the label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center') # horizontal alignment can be left, right or center
    
plt.savefig('compression.png')
